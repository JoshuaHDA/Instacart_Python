# %% [markdown]
# 1. Import Libraries and Dataframes
# 2. Groupby Function
# 3. Aggregate Function
# 4. Peform aggregates
# 5. Aggregate data with transform
# 6. Create Loyalty Flag

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#Define path
path = r'/Users/joshd/Documents/Personal/CareerFoundry/Instacart Basket Analysis'

# %%
#upload ords products merge file
ords_prods_merge = pd.read_pickle(r'/Users/joshd/Documents/Personal/CareerFoundry/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
#create subset
df = ords_prods_merge[:1000000]

# %%
#check shape
df.shape
# Out:
# (1000000, 21)

# %%
df.head(10)
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
# 5             0           1  Chocolate Sandwich Cookies        61
# 6             0           1  Chocolate Sandwich Cookies        61
# 7             0           1  Chocolate Sandwich Cookies        61
# 8             0           1  Chocolate Sandwich Cookies        61
# 9             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0             19     5.8          1987          1987   3139998      138  ...
# 1             19     5.8          1989          1989   1977647      138  ...
# 2             19     5.8         11433         11433    389851      709  ...
# 3             19     5.8         12198         12198    652770      764  ...
# 4             19     5.8         12200         12200   1813452      764  ...
# 5             19     5.8         12372         12372   1701441      777  ...
# 6             19     5.8         13096         13096   1871483      825  ...
# 7             19     5.8         14603         14603   1290456      910  ...
# 8             19     5.8         17065         17065    369558     1052  ...
# 9             19     5.8         17070         17070    589712     1052  ...
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   6                 11                     3.0
# 1                   6                 17                    20.0
# 2                   0                 21                     6.0
# 3                   3                 13                     0.0
# 4                   4                 17                     9.0
# 5                   1                  7                    26.0
# 6                   2                 14                    30.0
# 7                   3                 10                    30.0
# 8                   1                 20                    19.0
# 9                   1                 12                    15.0
#
#    add_to_cart_order  reordered  _merge exists    price_range_loc  \
# 0                  5          0    both   both  Mid-range product
# 1                  1          1    both   both  Mid-range product
# 2                 20          0    both   both  Mid-range product
# 3                 10          0    both   both  Mid-range product
# 4                 11          1    both   both  Mid-range product
# 5                  7          0    both   both  Mid-range product
# 6                  2          0    both   both  Mid-range product
# 7                  1          0    both   both  Mid-range product
# 8                  1          0    both   both  Mid-range product
# 9                  2          1    both   both  Mid-range product
#
#             busiest_day busiest_period_of_the_day
# 0        Regularly busy               Most orders
# 1        Regularly busy            Average orders
# 2           Busiest day            Average orders
# 3  Second to Least busy               Most orders
# 4            Least busy            Average orders
# 5   Second busiest busy            Average orders
# 6        Regularly busy               Most orders
# 7  Second to Least busy               Most orders
# 8   Second busiest busy            Average orders
# 9   Second busiest busy               Most orders
#
# [10 rows x 21 columns]

# %%
#groupby function
df.groupby('product_name')

# %%
#aggreate function
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
#test mean function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
#mean with a period
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
#perform multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %%
#aggregate data with transform
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# 13             0           1  Chocolate Sandwich Cookies        61
# 14             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0              19     5.8          1987          1987   3139998      138  ...
# 1              19     5.8          1989          1989   1977647      138  ...
# 2              19     5.8         11433         11433    389851      709  ...
# 3              19     5.8         12198         12198    652770      764  ...
# 4              19     5.8         12200         12200   1813452      764  ...
# 5              19     5.8         12372         12372   1701441      777  ...
# 6              19     5.8         13096         13096   1871483      825  ...
# 7              19     5.8         14603         14603   1290456      910  ...
# 8              19     5.8         17065         17065    369558     1052  ...
# 9              19     5.8         17070         17070    589712     1052  ...
# 10             19     5.8         22082         22082   1798115     1379  ...
# 11             19     5.8         23713         23713    497193     1480  ...
# 12             19     5.8         23715         23715   1727826     1480  ...
# 13             19     5.8         23716         23716   2694698     1480  ...
# 14             19     5.8         23937         23937   3171753     1494  ...
#
#     order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                  11                     3.0                  5          0
# 1                  17                    20.0                  1          1
# 2                  21                     6.0                 20          0
# 3                  13                     0.0                 10          0
# 4                  17                     9.0                 11          1
# 5                   7                    26.0                  7          0
# 6                  14                    30.0                  2          0
# 7                  10                    30.0                  1          0
# 8                  20                    19.0                  1          0
# 9                  12                    15.0                  2          1
# 10                 11                     0.0                  1          0
# 11                 13                     7.0                  1          0
# 12                 13                     7.0                  3          1
# 13                 12                    12.0                  4          1
# 14                 10                     2.0                  8          0
#
#     _merge  exists    price_range_loc           busiest_day  \
# 0     both    both  Mid-range product        Regularly busy
# 1     both    both  Mid-range product        Regularly busy
# 2     both    both  Mid-range product           Busiest day
# 3     both    both  Mid-range product  Second to Least busy
# 4     both    both  Mid-range product            Least busy
# 5     both    both  Mid-range product   Second busiest busy
# 6     both    both  Mid-range product        Regularly busy
# 7     both    both  Mid-range product  Second to Least busy
# 8     both    both  Mid-range product   Second busiest busy
# 9     both    both  Mid-range product   Second busiest busy
# 10    both    both  Mid-range product        Regularly busy
# 11    both    both  Mid-range product  Second to Least busy
# 12    both    both  Mid-range product            Least busy
# 13    both    both  Mid-range product        Regularly busy
# 14    both    both  Mid-range product  Second to Least busy
#
#    busiest_period_of_the_day max_order
# 0                Most orders        32
# 1             Average orders        32
# 2             Average orders         5
# 3                Most orders         3
# 4             Average orders         3
# 5             Average orders        26
# 6                Most orders         9
# 7                Most orders        12
# 8             Average orders        20
# 9                Most orders        20
# 10               Most orders        10
# 11               Most orders        43
# 12               Most orders        43
# 13               Most orders        43
# 14               Most orders        13
#
# [15 rows x 22 columns]

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# ..           ...         ...                         ...       ...
# 95             0           1  Chocolate Sandwich Cookies        61
# 96             0           1  Chocolate Sandwich Cookies        61
# 97             0           1  Chocolate Sandwich Cookies        61
# 98             0           1  Chocolate Sandwich Cookies        61
# 99             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  ...  \
# 0              19     5.8          1987          1987   3139998      138  ...
# 1              19     5.8          1989          1989   1977647      138  ...
# 2              19     5.8         11433         11433    389851      709  ...
# 3              19     5.8         12198         12198    652770      764  ...
# 4              19     5.8         12200         12200   1813452      764  ...
# ..            ...     ...           ...           ...       ...      ...  ...
# 95             19     5.8        179480        179480    602103    10831  ...
# 96             19     5.8        184011        184011     49629    11119  ...
# 97             19     5.8        185002        185002    317888    11186  ...
# 98             19     5.8        186194        186194    682486    11243  ...
# 99             19     5.8        189258        189258   2861386    11448  ...
#
#     order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                  11                     3.0                  5          0
# 1                  17                    20.0                  1          1
# 2                  21                     6.0                 20          0
# 3                  13                     0.0                 10          0
# 4                  17                     9.0                 11          1
# ..                ...                     ...                ...        ...
# 95                 11                    23.0                  5          0
# 96                 14                    30.0                  1          0
# 97                 16                     2.0                  8          0
# 98                 13                     0.0                  2          0
# 99                 15                     3.0                  6          0
#
#     _merge  exists    price_range_loc           busiest_day  \
# 0     both    both  Mid-range product        Regularly busy
# 1     both    both  Mid-range product        Regularly busy
# 2     both    both  Mid-range product           Busiest day
# 3     both    both  Mid-range product  Second to Least busy
# 4     both    both  Mid-range product            Least busy
# ..     ...     ...                ...                   ...
# 95    both    both  Mid-range product  Second to Least busy
# 96    both    both  Mid-range product   Second busiest busy
# 97    both    both  Mid-range product        Regularly busy
# 98    both    both  Mid-range product  Second to Least busy
# 99    both    both  Mid-range product        Regularly busy
#
#    busiest_period_of_the_day max_order
# 0                Most orders        32
# 1             Average orders        32
# 2             Average orders         5
# 3                Most orders         3
# 4             Average orders         3
# ..                       ...       ...
# 95               Most orders        10
# 96               Most orders        23
# 97            Average orders        26
# 98               Most orders        43
# 99               Most orders        21
#
# [100 rows x 22 columns]

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)

# %%
#label loyalty customers
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#check limited columns
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# 20     1540  Regular customer             7
# 21     1540  Regular customer             8
# 22     1540  Regular customer             9
# 23     1540  Regular customer            14
# 24     1540  Regular customer            15
# 25     1540  Regular customer            18
# 26     1540  Regular customer            19
# 27     1540  Regular customer            20
# 28     1540  Regular customer            21
# 29     1540  Regular customer            22
# 30     1540  Regular customer            24
# 31     1540  Regular customer            25
# 32     1540  Regular customer            27
# 33     1540  Regular customer            28
# 34     1598      New customer             1
# 35     1598      New customer             2
# 36     1598      New customer             3
# 37     1647      New customer             1
# 38     1647      New customer             4
# 39     1647      New customer             6
# 40     1647      New customer             8
# 41     1647      New customer             9
# 42     2833      New customer             1
# 43     2850  Regular customer             7
# 44     2857  Regular customer            24
# 45     3010  Regular customer             5
# 46     3029      New customer             1
# 47     3395      New customer             4
# 48     3904      New customer             1
# 49     4006    Loyal customer             2
# 50     4006    Loyal customer             3
# 51     4006    Loyal customer             5
# 52     4006    Loyal customer             9
# 53     4006    Loyal customer            12
# 54     4122  Regular customer            11
# 55     4141      New customer             2
# 56     4343      New customer             1
# 57     4553      New customer             3
# 58     4845  Regular customer             6
# 59     6866      New customer             1
